# %%
## import requierd libraries

## Let ingest all customers for use


# set customers rules

p_rule = {'rule': 'customer_id is not null'}

@dlt.table(
  name = "customers",
  comment = "expect_all_or_drop(p_rules)"
 
)
def customers():
  return spark.readStream.table("hubmart1_catalog.hubmart1_schema.customers")
