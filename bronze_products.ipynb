# %%
## import requierd libraries

## Let ingest all products for use


# set products rules

p_rule = {'rule': 'product_id is not null'}

@dlt.table(
  name = "products",
  comment = "expect_all_or_drop(p_rules)"
 
)
def products():
  return spark.readStream.table("hubmart1_catalog.hubmart1_schema.products")
